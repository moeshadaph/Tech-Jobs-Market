-- %%
SELECT * FROM tech_jobs_market.pipeline.top_skills LIMIT 10;
SELECT * FROM tech_jobs_market.pipeline.salary_by_level;
SELECT * FROM tech_jobs_market.pipeline.jobs_by_city ORDER BY nb_offres DESC;
SELECT * FROM tech_jobs_market.pipeline.top_skills ORDER BY nb_offres DESC LIMIT 10;
